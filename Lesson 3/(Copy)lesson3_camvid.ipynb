# %% [markdown]
# <a href="https://colab.research.google.com/github/amannarsaria4/fast.ai/blob/master/Lesson%203/(Copy)lesson3_camvid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Image segmentation with CamVid

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.callbacks.hooks import *
from fastai.utils.mem import *

# %%
path = untar_data(URLs.CAMVID)
path.ls()
# Out:
# Downloading https://s3.amazonaws.com/fast-ai-imagelocal/camvid.tgz
# [PosixPath('/root/.fastai/data/camvid/codes.txt'),
#  PosixPath('/root/.fastai/data/camvid/labels'),
#  PosixPath('/root/.fastai/data/camvid/valid.txt'),
#  PosixPath('/root/.fastai/data/camvid/images')]

# %%
path_lbl = path/'labels'
path_img = path/'images'

# %% [markdown]
# ## Subset classes

# %%
# path = Path('./data/camvid-small')

# def get_y_fn(x): return Path(str(x.parent)+'annot')/x.name

# codes = array(['Sky', 'Building', 'Pole', 'Road', 'Sidewalk', 'Tree',
#     'Sign', 'Fence', 'Car', 'Pedestrian', 'Cyclist', 'Void'])

# src = (SegmentationItemList.from_folder(path)
#        .split_by_folder(valid='val')
#        .label_from_func(get_y_fn, classes=codes))

# bs=8
# data = (src.transform(get_transforms(), tfm_y=True)
#         .databunch(bs=bs)
#         .normalize(imagenet_stats))

# %% [markdown]
# ## Data

# %%
fnames = get_image_files(path_img)
fnames[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/images/0001TP_006810.png'),
#  PosixPath('/root/.fastai/data/camvid/images/Seq05VD_f01530.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0001TP_008880.png')]

# %%
lbl_names = get_image_files(path_lbl)
lbl_names[:3]
# Out:
# [PosixPath('/root/.fastai/data/camvid/labels/0006R0_f02580_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0006R0_f01020_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0016E5_04800_P.png')]

# %%
img_f = fnames[0]
img = open_image(img_f)
img.show(figsize=(5,5))

# %%
get_y_fn = lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
mask = open_mask(get_y_fn(img_f))
mask.show(figsize=(5,5), alpha=1)

# %%
src_size = np.array(mask.shape[1:])
src_size,mask.data
# Out:
# (array([720, 960]), tensor([[[ 4,  4,  4,  ...,  4,  4,  4],
#           [ 4,  4,  4,  ...,  4,  4,  4],
#           [ 4,  4,  4,  ...,  4,  4,  4],
#           ...,
#           [19, 19, 19,  ..., 30, 30, 30],
#           [19, 19, 19,  ..., 30, 30, 30],
#           [19, 19, 19,  ..., 30, 30, 30]]]))

# %%
codes = np.loadtxt(path/'codes.txt', dtype=str); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %% [markdown]
# ## Datasets

# %%
size = src_size//2

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=8
else:           bs=4
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# using bs=8, have 11430MB of GPU RAM free

# %%
src = (SegmentationItemList.from_folder(path_img)
       .split_by_fname_file('../valid.txt')
       .label_from_func(get_y_fn, classes=codes))

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
data.show_batch(2, figsize=(10,7))

# %%
data.show_batch(2, figsize=(10,7), ds_type=DatasetType.Valid)

# %% [markdown]
# ## Model

# %%
name2id = {v:k for k,v in enumerate(codes)}
void_code = name2id['Void']

def acc_camvid(input, target):
    target = target.squeeze(1)
    mask = target != void_code
    return (input.argmax(dim=1)[mask]==target[mask]).float().mean()

# %%
metrics=acc_camvid
# metrics=accuracy

# %%
wd=1e-2

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/checkpoints/resnet34-333f7ec4.pth
# HBox(children=(FloatProgress(value=0.0, max=87306240.0), HTML(value='')))

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/2 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='72' class='' max='75' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       96.00% [72/75 03:04<00:07 11.6804]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=3e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.9)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.339645</td>
#       <td>0.914148</td>
#       <td>0.784950</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.905469</td>
#       <td>0.713884</td>
#       <td>0.818737</td>
#       <td>03:09</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.718479</td>
#       <td>0.541120</td>
#       <td>0.861941</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.674077</td>
#       <td>0.576363</td>
#       <td>0.857571</td>
#       <td>03:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.658030</td>
#       <td>0.491919</td>
#       <td>0.878165</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.606519</td>
#       <td>0.525559</td>
#       <td>0.872526</td>
#       <td>03:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.570630</td>
#       <td>0.482916</td>
#       <td>0.871264</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.565175</td>
#       <td>0.455824</td>
#       <td>0.882271</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.548034</td>
#       <td>0.354060</td>
#       <td>0.902835</td>
#       <td>03:05</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.465531</td>
#       <td>0.331641</td>
#       <td>0.903907</td>
#       <td>03:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.load('stage-1');

# %%
learn.show_results(rows=3, figsize=(8,9))

# %%
learn.unfreeze()

# %%
lrs = slice(lr/400,lr/4)

# %%
learn.fit_one_cycle(12, lrs, pct_start=0.8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.394491</td>
#       <td>0.319107</td>
#       <td>0.905844</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.381094</td>
#       <td>0.317725</td>
#       <td>0.905590</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.376712</td>
#       <td>0.293227</td>
#       <td>0.917331</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.359269</td>
#       <td>0.308011</td>
#       <td>0.911466</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.350381</td>
#       <td>0.299961</td>
#       <td>0.911804</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.336220</td>
#       <td>0.286171</td>
#       <td>0.918316</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.328580</td>
#       <td>0.285856</td>
#       <td>0.923853</td>
#       <td>03:14</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.321243</td>
#       <td>0.296072</td>
#       <td>0.915640</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.317263</td>
#       <td>0.274116</td>
#       <td>0.917461</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.303912</td>
#       <td>0.273541</td>
#       <td>0.922206</td>
#       <td>03:13</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.274064</td>
#       <td>0.268546</td>
#       <td>0.925085</td>
#       <td>03:12</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.252421</td>
#       <td>0.264836</td>
#       <td>0.926164</td>
#       <td>03:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2');

# %% [markdown]
# ## Go big

# %% [markdown]
# You may have to restart your kernel and come back to this stage if you run out of memory, and may also need to decrease `bs`.

# %%
learn.destroy()

size = src_size

free = gpu_mem_get_free_no_cache()
# the max size of bs depends on the available GPU RAM
if free > 8200: bs=3
else:           bs=1
print(f"using bs={bs}, have {free}MB of GPU RAM free")
# Out:
# this Learner object self-destroyed - it still exists, but no longer usable
# using bs=3, have 11119MB of GPU RAM free

# %%
data = (src.transform(get_transforms(), size=size, tfm_y=True)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# %%
learn = unet_learner(data, models.resnet34, metrics=metrics, wd=wd)

# %%
learn.load('stage-2');

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='66' class='' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       33.00% [66/200 04:32<09:12 0.6153]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-3

# %%
learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       10.00% [1/10 13:39<2:02:57]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>acc_camvid</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.374341</td>
#       <td>0.341759</td>
#       <td>0.903551</td>
#       <td>13:39</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='200' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       1.00% [2/200 00:08<14:28 0.3743]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-38-ffa2f051ddcd> in <module>()
# ----> 1 learn.fit_one_cycle(10, slice(lr), pct_start=0.8)
#
# /usr/local/lib/python3.6/dist-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# /usr/local/lib/python3.6/dist-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      32     if opt is not None:
#      33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
# ---> 34         if not skip_bwd:                     loss.backward()
#      35         if not cb_handler.on_backward_end(): opt.step()
#      36         if not cb_handler.on_step_end():     opt.zero_grad()
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     196                 products. Defaults to ``False``.
#     197         """
# --> 198         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     199
#     200     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      98     Variable._execution_engine.run_backward(
#      99         tensors, grad_tensors, retain_graph, create_graph,
# --> 100         allow_unreachable=True)  # allow_unreachable flag
#     101
#     102
#
# RuntimeError: CUDA out of memory. Tried to allocate 784.00 MiB (GPU 0; 11.17 GiB total capacity; 8.44 GiB already allocated; 589.81 MiB free; 10.28 GiB reserved in total by PyTorch) (malloc at /pytorch/c10/cuda/CUDACachingAllocator.cpp:289)
# frame #0: c10::Error::Error(c10::SourceLocation, std::string const&) + 0x46 (0x7fe1e888b536 in /usr/local/lib/python3.6/dist-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0x1cf1e (0x7fe1e8ad4f1e in /usr/local/lib/python3.6/dist-packages/torch/lib/libc10_cuda.so)
# frame #2: <unknown function> + 0x1df9e (0x7fe1e8ad5f9e in /usr/local/lib/python3.6/dist-packages/torch/lib/libc10_cuda.so)
# frame #3: at::native::empty_cuda(c10::ArrayRef<long>, c10::TensorOptions const&, c10::optional<c10::MemoryFormat>) + 0x135 (0x7fe1eb67c475 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0xf8135b (0x7fe1e9c6835b in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #5: <unknown function> + 0xfcac47 (0x7fe1e9cb1c47 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #6: <unknown function> + 0x1073c49 (0x7fe221810c49 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #7: <unknown function> + 0x1073f87 (0x7fe221810f87 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #8: <unknown function> + 0xf1c26e (0x7fe1e9c0326e in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #9: <unknown function> + 0xf1ed33 (0x7fe1e9c05d33 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #10: at::native::cudnn_convolution_backward_input(c10::ArrayRef<long>, at::Tensor const&, at::Tensor const&, c10::ArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, long, bool, bool) + 0xb2 (0x7fe1e9c06572 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #11: <unknown function> + 0xf86090 (0x7fe1e9c6d090 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #12: <unknown function> + 0xfca928 (0x7fe1e9cb1928 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #13: at::native::cudnn_convolution_backward(at::Tensor const&, at::Tensor const&, at::Tensor const&, c10::ArrayRef<long>, c10::ArrayRef<long>, c10::ArrayRef<long>, long, bool, bool, std::array<bool, 2ul>) + 0x4fa (0x7fe1e9c07c0a in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #14: <unknown function> + 0xf863bb (0x7fe1e9c6d3bb in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #15: <unknown function> + 0xfca984 (0x7fe1e9cb1984 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cuda.so)
# frame #16: <unknown function> + 0x2c80736 (0x7fe22341d736 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #17: <unknown function> + 0x2ccff44 (0x7fe22346cf44 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #18: torch::autograd::generated::CudnnConvolutionBackward::apply(std::vector<at::Tensor, std::allocator<at::Tensor> >&&) + 0x378 (0x7fe223035908 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #19: <unknown function> + 0x2d89705 (0x7fe223526705 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #20: torch::autograd::Engine::evaluate_function(std::shared_ptr<torch::autograd::GraphTask>&, torch::autograd::Node*, torch::autograd::InputBuffer&) + 0x16f3 (0x7fe223523a03 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #21: torch::autograd::Engine::thread_main(std::shared_ptr<torch::autograd::GraphTask> const&, bool) + 0x3d2 (0x7fe2235247e2 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #22: torch::autograd::Engine::thread_init(int) + 0x39 (0x7fe22351ce59 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_cpu.so)
# frame #23: torch::autograd::python::PythonEngine::thread_init(int) + 0x38 (0x7fe22fe64488 in /usr/local/lib/python3.6/dist-packages/torch/lib/libtorch_python.so)
# frame #24: <unknown function> + 0xbd6df (0x7fe25d60a6df in /usr/lib/x86_64-linux-gnu/libstdc++.so.6)
# frame #25: <unknown function> + 0x76db (0x7fe25e6ec6db in /lib/x86_64-linux-gnu/libpthread.so.0)
# frame #26: clone + 0x3f (0x7fe25ea25a3f in /lib/x86_64-linux-gnu/libc.so.6)

# %%
learn.save('stage-1-big')

# %%
learn.load('stage-1-big');

# %%
learn.unfreeze()

# %%
lrs = slice(1e-6,lr/10)

# %%
learn.fit_one_cycle(10, lrs)

# %%
learn.save('stage-2-big')

# %%
learn.load('stage-2-big');

# %%
learn.show_results(rows=3, figsize=(10,10))
